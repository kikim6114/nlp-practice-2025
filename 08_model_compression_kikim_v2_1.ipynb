# %% [markdown]
# <table align="left"><tr><td>
# <a href="https://colab.research.google.com/github/rickiepark/nlp-with-transformers/blob/main/08_model-compression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="코랩에서 실행하기"/></a>
# </td></tr></table>

# %%
# 코랩이나 캐글을 사용한다면 이 셀의 주석을 제거하고 실행하세요.
# !git clone https://github.com/kikim6114/nlp2026-transformers.git
# %cd nlp2026-transformers
from install import *
install_requirements(chapter=8)
# Out:
# Cloning into 'nlp2026-transformers'...
# remote: Enumerating objects: 904, done.
# remote: Counting objects: 100% (185/185), done.
# remote: Compressing objects: 100% (126/126), done.
# remote: Total 904 (delta 124), reused 101 (delta 58), pack-reused 719 (from 3)
# Receiving objects: 100% (904/904), 216.54 MiB | 27.27 MiB/s, done.
# Resolving deltas: 100% (290/290), done.
# Updating files: 100% (682/682), done.
# /content/nlp2026-transformers/nlp2026-transformers
# ⏳ Installing base requirements ...
# ✅ Base requirements installed!
# Using transformers v5.9.0
# Using accelerate v1.13.0
# Using optuna v4.9.0
# Using onnxruntime v1.26.0
# Using onnx v1.21.0

# %%
# !pip uninstall gcsfs
# !pip install gcsfs==2025.3.0
# !pip install fsspec==2025.3.0
# !pip install -U huggingface_hub datasets
# Out:
# Found existing installation: gcsfs 2025.3.0
# Uninstalling gcsfs-2025.3.0:
#   Would remove:
#     /usr/local/lib/python3.12/dist-packages/gcsfs-2025.3.0.dist-info/*
#     /usr/local/lib/python3.12/dist-packages/gcsfs/*
# Proceed (Y/n)? y
#   Successfully uninstalled gcsfs-2025.3.0
# Collecting gcsfs==2025.3.0
#   Using cached gcsfs-2025.3.0-py2.py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from gcsfs==2025.3.0) (3.14.0)
# Requirement already satisfied: decorator>4.1.2 in /usr/local/lib/python3.12/dist-packages (from gcsfs==2025.3.0) (4.4.2)
# Requirement already satisfied: fsspec==2025.3.0 in /usr/local/lib/python3.12/dist-packages (from gcsfs==2025.3.0) (2025.3.0)
# Requirement already satisfied: google-auth>=1.2 in /usr/local/lib/python3.12/dist-packages (from gcsfs==2025.3.0) (2.47.0)
# Requirement already satisfied: google-auth-oauthlib in /usr/local/lib/python3.12/dist-packages (from gcsfs==2025.3.0) (1.4.0)
# Requirement already satisfied: google-cloud-storage in /usr/local/lib/python3.12/dist-packages (from gcsfs==2025.3.0) (3.10.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from gcsfs==2025.3.0) (2.32.4)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs==2025.3.0) (2.6.2)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs==2025.3.0) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs==2025.3.0) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs==2025.3.0) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs==2025.3.0) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs==2025.3.0) (0.5.2)
# Requirement already satisfied: typing_extensions>=4.4 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs==2025.3.0) (4.15.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs==2025.3.0) (1.24.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth>=1.2->gcsfs==2025.3.0) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth>=1.2->gcsfs==2025.3.0) (4.9.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from google-auth-oauthlib->gcsfs==2025.3.0) (2.0.0)
# Requirement already satisfied: google-api-core<3.0.0,>=2.27.0 in /usr/local/lib/python3.12/dist-packages (from google-cloud-storage->gcsfs==2025.3.0) (2.30.3)
# Requirement already satisfied: google-cloud-core<3.0.0,>=2.4.2 in /usr/local/lib/python3.12/dist-packages (from google-cloud-storage->gcsfs==2025.3.0) (2.6.0)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.7.2 in /usr/local/lib/python3.12/dist-packages (from google-cloud-storage->gcsfs==2025.3.0) (2.9.0)
# Requirement already satisfied: google-crc32c<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from google-cloud-storage->gcsfs==2025.3.0) (1.8.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->gcsfs==2025.3.0) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->gcsfs==2025.3.0) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->gcsfs==2025.3.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->gcsfs==2025.3.0) (2026.5.20)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.63.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core<3.0.0,>=2.27.0->google-cloud-storage->gcsfs==2025.3.0) (1.75.0)
# Requirement already satisfied: protobuf<8.0.0,>=4.25.8 in /usr/local/lib/python3.12/dist-packages (from google-api-core<3.0.0,>=2.27.0->google-cloud-storage->gcsfs==2025.3.0) (5.29.6)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /usr/local/lib/python3.12/dist-packages (from google-api-core<3.0.0,>=2.27.0->google-cloud-storage->gcsfs==2025.3.0) (1.28.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.2->gcsfs==2025.3.0) (0.6.3)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib->gcsfs==2025.3.0) (3.3.1)
# Using cached gcsfs-2025.3.0-py2.py3-none-any.whl (36 kB)
# Installing collected packages: gcsfs
# Successfully installed gcsfs-2025.3.0
# Requirement already satisfied: fsspec==2025.3.0 in /usr/local/lib/python3.12/dist-packages (2025.3.0)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.12/dist-packages (1.18.0)
# Requirement already satisfied: datasets in /usr/local/lib/python3.12/dist-packages (5.0.0)
# Requirement already satisfied: click>=8.4.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (8.4.1)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (3.29.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (1.5.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (0.28.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (26.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (6.0.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (4.67.3)
# Requirement already satisfied: typer<0.26.0,>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (0.25.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (4.15.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from datasets) (2.0.2)
# Requirement already satisfied: pyarrow>=21.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (24.0.0)
# Requirement already satisfied: dill<0.4.2,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.12/dist-packages (from datasets) (2.32.4)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets) (3.7.0)
# Requirement already satisfied: multiprocess<0.70.20 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2026.4.0,>=2023.1.0->datasets) (3.14.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub) (4.13.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub) (3.18)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface_hub) (0.16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (2.5.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<0.26.0,>=0.20.0->huggingface_hub) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /usr/local/lib/python3.12/dist-packages (from typer<0.26.0,>=0.20.0->huggingface_hub) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer<0.26.0,>=0.20.0->huggingface_hub) (0.0.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2026.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.4.0,>=2023.1.0->datasets) (2.6.2)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.4.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.4.0,>=2023.1.0->datasets) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.4.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.4.0,>=2023.1.0->datasets) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.4.0,>=2023.1.0->datasets) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.4.0,>=2023.1.0->datasets) (1.24.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface_hub) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface_hub) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface_hub) (0.1.2)

# %% [markdown]
# # 8. 효율적인 트랜스포머 구축
#
# #### 작지만 빠르고 정확도 높은 모델이 필요하다면?
# #### 예측 속도를 높이고 트랜스포머 모델의 메모리 사용량을 줄이는 기술 4 가지:
# - 지식 정제(Knowledge Distillation)
# - 양자화(Quantization)
# - 가지치기(Pruning)
# - ONNX 포맷과 ONNX 런타임(ORT)을 사용한 그래프 최적화(Graph Optimization)

# %% [markdown]
# <img alt="Scaling BERT at Roblox" caption="How Roblox scaled BERT with knowledge distillation, dynamic padding, and weight quantization (photo courtesy of Roblox employees Quoc N. Le and Kip Kaehler)" src="https://github.com/kikim6114/nlp2026-transformers/blob/main/images/chapter08_roblox.png?raw=1" width="800" id="roblox"/>
# <p align="center">[그림 8-1] Roblox가 지식 정제, 동적 패딩, 가중치 양자화로 BERT를 스케일링한 예(로블록스 직원인 Quoc N. Le와 Kip Kaehler 제공)
# </p>
# <br>
# * 지식 정제와 양자화를 연결해 레이턴시와 BERT 분류기의 처리 성능을 30배 이상 향상시킴

# %% [markdown]
# ## 8.1 의도 탐지 예제
# - 금융사 콜센터 전용 텍스트 기반 어시스턴스 시스템 구축하기
# - 의도 탐지(Intent Detection):
#   - 텍스트 기반 어시스턴스 시스템에서 중요한 구성 요소
#   - 사용자 쿼리를 사전에 정의된 일련의 행동이나 의도로 분류하고 후속 작업(예: 렌트가 예약이면 렌트가 예약 관련 대화로 전환)
#   - 대화 유지를 위해서 latency가 낮아야 한다
#   - 사용자가 정의된 의도에 속하지 않은 쿼리를 제공하면 이에 대하여 응답을 출력해야 한다.

# %% [markdown]
# <img alt="Out of Scope Query" width="300" caption="Three exchanges between a human (right) and a text-based assistant (left) for personal finance (courtesy of Stefan Larson et al.)" src="https://github.com/rickiepark/nlp-with-transformers/blob/main/images/chapter08_oos.png?raw=1" id="oos"/>
# <p>[그림 8-2] 사람(오른쪽)과 텍스트 기반 어시스턴트(왼쪽)가 개인 금융정보에 대해 나눈 대화(Stefan Larson 등이 제공)
# </p>

# %% [markdown]
# ##### 기준 모델: CLINIC150 dataset에서 fine-tuning된 BERT base 모델(정확도: 94%)
# ##### CLINIC150 dataset:
# - 150 개 intent classes
# - 22,500 queries for 10 개 domains
# - 1,200 queries for oos class(Out-Of-Scope class)

# %%
from transformers import pipeline
# 허깅페이스 허브에서 미세 튜닝한 모델을 다운로드 하고 위 사진의 태스크를 진행
bert_ckpt = "transformersbook/bert-base-uncased-finetuned-clinc"
pipe = pipeline("text-classification", model=bert_ckpt)
# Out:
# Loading weights:   0%|          | 0/201 [00:00<?, ?it/s]

# %%
query = """Hey, I'd like to rent a vehicle from Nov 1st to Nov 15th in
Paris and I need a 15 passenger van"""
pipe(query)
# Out:
# [{'label': 'car_rental', 'score': 0.5490034222602844}]

# %% [markdown]
# ## 8.2 벤치마크 클래스 만들기
# #### 트랜스포머를 제품 환경에 배포하기 위해 절충해야 할 제약 조건들:
# - 모델 성능
# - 레이턴시
# - 메모리
#
#
# ##### 이러한 제약들을 다양한 압축 기법으로 최적화하는 방법을 알아본다.

# %%
class PerformanceBenchmark:
    def __init__(self, pipeline, dataset, optim_type="BERT baseline"):
        self.pipeline = pipeline
        self.dataset = dataset
        self.optim_type = optim_type

    def compute_accuracy(self):
        # 나중에 정의합니다
        pass

    def compute_size(self):
        # 나중에 정의합니다
        pass

    def time_pipeline(self):
        # 나중에 정의합니다
        pass

    def run_benchmark(self):
        metrics = {}
        metrics[self.optim_type] = self.compute_size()
        metrics[self.optim_type].update(self.time_pipeline())
        metrics[self.optim_type].update(self.compute_accuracy())
        return metrics

# %% [markdown]
# #### 테스트셋에서 모델 정확도 계산

# %%
from datasets import load_dataset

# 변경 후
clinc = load_dataset("clinc/clinc_oos", "plus")

# %%
clinc
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['text', 'intent'],
#         num_rows: 15250
#     })
#     validation: Dataset({
#         features: ['text', 'intent'],
#         num_rows: 3100
#     })
#     test: Dataset({
#         features: ['text', 'intent'],
#         num_rows: 5500
#     })
# })

# %%
import pandas as pd
pd.DataFrame(clinc["test"][40:45])
# Out:
#                                                 text  intent
# 0  i would like to transfer $100 from my checking...     133
# 1  help me transfer $100 from my checking to savi...     133
# 2   transfer $100 from my checking to saving account     133
# 3  can you please help me move $100 from my check...     133
# 4  please move $100 from my checking to saving ac...     133

# %%
sample = clinc["test"][42]
sample
# Out:
# {'text': 'transfer $100 from my checking to saving account', 'intent': 133}

# %%
clinc["test"].features["intent"]
# Out:
# ClassLabel(names=['restaurant_reviews', 'nutrition_info', 'account_blocked', 'oil_change_how', 'time', 'weather', 'redeem_rewards', 'interest_rate', 'gas_type', 'accept_reservations', 'smart_home', 'user_name', 'report_lost_card', 'repeat', 'whisper_mode', 'what_are_your_hobbies', 'order', 'jump_start', 'schedule_meeting', 'meeting_schedule', 'freeze_account', 'what_song', 'meaning_of_life', 'restaurant_reservation', 'traffic', 'make_call', 'text', 'bill_balance', 'improve_credit_score', 'change_language', 'no', 'measurement_conversion', 'timer', 'flip_coin', 'do_you_have_pets', 'balance', 'tell_joke', 'last_maintenance', 'exchange_rate', 'uber', 'car_rental', 'credit_limit', 'oos', 'shopping_list', 'expiration_date', 'routing', 'meal_suggestion', 'tire_change', 'todo_list', 'card_declined', 'rewards_balance', 'change_accent', 'vaccines', 'reminder_update', 'food_last', 'change_ai_name', 'bill_due', 'who_do_you_work_for', 'share_location', 'international_visa', 'calendar', 'translate', 'carry_on', 'book_flight', 'insurance_change', 'todo_list_update', 'timezone', 'cancel_reservation', 'transactions', 'credit_score', 'report_fraud', 'spending_history', 'directions', 'spelling', 'insurance', 'what_is_your_name', 'reminder', 'where_are_you_from', 'distance', 'payday', 'flight_status', 'find_phone', 'greeting', 'alarm', 'order_status', 'confirm_reservation', 'cook_time', 'damaged_card', 'reset_settings', 'pin_change', 'replacement_card_duration', 'new_card', 'roll_dice', 'income', 'taxes', 'date', 'who_made_you', 'pto_request', 'tire_pressure', 'how_old_are_you', 'rollover_401k', 'pto_request_status', 'how_busy', 'application_status', 'recipe', 'calendar_update', 'play_music', 'yes', 'direct_deposit', 'credit_limit_change', 'gas', 'pay_bill', 'ingredients_list', 'lost_luggage', 'goodbye', 'what_can_i_ask_you', 'book_hotel', 'are_you_a_bot', 'next_song', 'change_speed', 'plug_type', 'maybe', 'w2', 'oil_change_when', 'thank_you', 'shopping_list_update', 'pto_balance', 'order_checks', 'travel_alert', 'fun_fact', 'sync_device', 'schedule_maintenance', 'apr', 'transfer', 'ingredient_substitution', 'calories', 'current_location', 'international_fees', 'calculator', 'definition', 'next_holiday', 'update_playlist', 'mpg', 'min_payment', 'change_user_name', 'restaurant_suggestion', 'travel_notification', 'cancel', 'pto_used', 'travel_suggestion', 'change_volume'])

# %%
len(clinc["test"].features["intent"].names)
# Out:
# 151

# %% [markdown]
# `ClassLabel`: HuggingFace의 datasets 라이브러리에서 사용되는 기능. 범주형 데이터가 포함된 데이터셋의 열을 나타내는 데 사용되며, 각 범주는 레이블과 연관됨. 레이블은 내부적으로 정수로 저장되며, 정수 표현과 문자열 레이블 간 변환을 위한 메서드 제공.

# %%
intents = clinc["test"].features["intent"]
intents.int2str(sample["intent"])
# Out:
# 'transfer'

# %% [markdown]
# #### `PerformanceBenchmark`의 `computer_accuracy()` 구현
# ##### 🤗 [`evaluate`](https://pypi.org/project/evaluate/):  모델을 평가하고 비교하며, 성능 리포트를 보다 쉽고 표준화된 방식으로 만들어 주는 라이브러리

# %%
# !pip install evaluate
# Out:
# Requirement already satisfied: evaluate in /usr/local/lib/python3.12/dist-packages (0.4.6)
# Requirement already satisfied: datasets>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from evaluate) (5.0.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from evaluate) (2.0.2)
# Requirement already satisfied: dill in /usr/local/lib/python3.12/dist-packages (from evaluate) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from evaluate) (2.2.2)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.12/dist-packages (from evaluate) (2.32.4)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.12/dist-packages (from evaluate) (4.67.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from evaluate) (3.7.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.12/dist-packages (from evaluate) (0.70.16)
# Requirement already satisfied: fsspec>=2021.05.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]>=2021.05.0->evaluate) (2025.3.0)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from evaluate) (1.18.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from evaluate) (26.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from datasets>=2.0.0->evaluate) (3.29.0)
# Requirement already satisfied: pyarrow>=21.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.0.0->evaluate) (24.0.0)
# Requirement already satisfied: httpx<1.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.0.0->evaluate) (0.28.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.0.0->evaluate) (6.0.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]>=2021.05.0->evaluate) (3.14.0)
# Requirement already satisfied: click>=8.4.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.7.0->evaluate) (8.4.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.7.0->evaluate) (1.5.0)
# Requirement already satisfied: typer<0.26.0,>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.7.0->evaluate) (0.25.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.7.0->evaluate) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->evaluate) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->evaluate) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->evaluate) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->evaluate) (2026.5.20)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->evaluate) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->evaluate) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->evaluate) (2026.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (2.6.2)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.24.2)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->datasets>=2.0.0->evaluate) (4.13.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->datasets>=2.0.0->evaluate) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0.0->datasets>=2.0.0->evaluate) (0.16.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->evaluate) (1.17.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<0.26.0,>=0.20.0->huggingface-hub>=0.7.0->evaluate) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /usr/local/lib/python3.12/dist-packages (from typer<0.26.0,>=0.20.0->huggingface-hub>=0.7.0->evaluate) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer<0.26.0,>=0.20.0->huggingface-hub>=0.7.0->evaluate) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface-hub>=0.7.0->evaluate) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface-hub>=0.7.0->evaluate) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface-hub>=0.7.0->evaluate) (0.1.2)

# %%
import evaluate

accuracy_score = evaluate.load("accuracy")  # 정확도 metric 로드
# Out:
# Downloading builder script: 0.00B [00:00, ?B/s]

# %%
def compute_accuracy(self):
    """PerformanceBenchmark.compute_accuracy() 메서드를 오버라이드"""
    preds, labels = [], []
    for example in self.dataset:
        pred = self.pipeline(example["text"])[0]["label"]  # pipeline 출력 내용 예:  [{'label': 'car_rental', 'score': 0.549003541469574}]
        label = example["intent"]
        preds.append(intents.str2int(pred))
        labels.append(label)
    accuracy = accuracy_score.compute(predictions=preds, references=labels)
    print(f"테스트 세트 정확도 - {accuracy['accuracy']:.3f}")
    return accuracy

PerformanceBenchmark.compute_accuracy = compute_accuracy

# %% [markdown]
# ##### `torch.save()` 함수를 사용해 모델을 디스크에 직렬화하고 크기를 계산
# ##### `state_dict()` 메소드는 모델의 층과 학습가능 파라미터를 매핑하는 딕셔너리 반환

# %%
list(pipe.model.state_dict().items())[42]
# Out:
# ('bert.encoder.layer.2.attention.self.value.bias',
#  tensor([-2.7834e-02,  4.9434e-02,  8.3551e-02,  4.1092e-02,  6.0157e-01,
#           1.1774e-01, -5.2112e-02, -6.5143e-02, -2.9358e-02, -4.2250e-02,
#           7.9177e-02,  8.0409e-02,  2.9921e-03,  1.7816e-01, -5.0480e-02,
#          -1.5634e-01, -2.1707e-02,  1.4381e-02,  2.5132e-02, -2.4110e-02,
#          -1.9183e-01, -7.8657e-02,  5.0709e-02,  3.3632e-02, -3.1946e-02,
#           1.1616e-01,  9.2720e-02, -1.1787e-01,  2.3233e-01, -1.2678e-02,
#           1.0347e-02, -3.4209e-02,  1.6939e-02,  1.8120e-02,  3.0650e-03,
#          -2.5109e-03,  1.3500e-02, -3.6440e-02, -9.2135e-03,  9.2194e-03,
#          -3.6276e-02, -1.1555e-02, -1.9569e-02, -1.5417e-02, -2.0485e-02,
#           2.9770e-03, -6.8246e-03, -6.5039e-03, -1.2597e-02, -1.1409e-02,
#           1.7139e-02,  4.6424e-03, -5.1774e-02, -1.1679e-02,  5.2761e-03,
#          -1.3664e-02, -1.4001e-02,  2.0379e-03,  1.2753e-02, -8.1607e-03,
#          -1.0849e-02, -1.0683e-03, -2.4489e-03,  2.0192e-02,  1.5756e-02,
#          -6.4964e-03, -4.5603e-02, -2.5999e-02, -1.4307e-02, -7.4639e-03,
#           9.9480e-03,  1.6763e-02,  2.1737e-02,  4.8181e-02,  1.7739e-02,
#           1.1469e-02, -4.2359e-03, -1.6419e-02, -1.7318e-02,  1.1498e-03,
#           2.4485e-02, -3.0614e-03,  1.9017e-02, -1.6453e-02, -1.3444e-02,
#           2.6748e-02, -6.4994e-03,  5.1485e-03,  1.4132e-02, -1.1573e-02,
#           1.2583e-02, -1.1401e-02, -2.0003e-02, -3.8115e-03,  7.3728e-03,
#           1.5500e-02,  2.0623e-02,  3.1582e-03, -1.2794e-02,  4.5499e-03,
#          -3.3994e-04, -2.3003e-02,  1.2225e-02, -2.7949e-02, -9.6121e-03,
#          -3.5844e-02, -4.2373e-03,  5.3473e-03,  1.4432e-02, -1.2745e-02,
#           7.1483e-03,  2.9170e-03,  6.2454e-03,  6.8991e-03,  1.5852e-02,
#           2.1877e-02, -1.7211e-02, -2.6093e-02], device='cuda:0'))

# %%
for i, param_tensor in enumerate(pipe.model.state_dict()):
    print(f"{i}\t{param_tensor}\t{pipe.model.state_dict()[param_tensor].size()}")
# Out:
# 0       bert.embeddings.word_embeddings.weight  torch.Size([30522, 768])
# 1       bert.embeddings.position_embeddings.weight      torch.Size([512, 768])
# 2       bert.embeddings.token_type_embeddings.weight    torch.Size([2, 768])
# 3       bert.embeddings.LayerNorm.weight        torch.Size([768])
# 4       bert.embeddings.LayerNorm.bias  torch.Size([768])
# 5       bert.encoder.layer.0.attention.self.query.weight        torch.Size([768,
# 768])
# 6       bert.encoder.layer.0.attention.self.query.bias  torch.Size([768])
# 7       bert.encoder.layer.0.attention.self.key.weight  torch.Size([768, 768])
# 8       bert.encoder.layer.0.attention.self.key.bias    torch.Size([768])
# 9       bert.encoder.layer.0.attention.self.value.weight        torch.Size([768,
# 768])
# 10      bert.encoder.layer.0.attention.self.value.bias  torch.Size([768])
# 11      bert.encoder.layer.0.attention.output.dense.weight      torch.Size([768,
# 768])
# 12      bert.encoder.layer.0.attention.output.dense.bias
# torch.Size([768])
# 13      bert.encoder.layer.0.attention.output.LayerNorm.weight
# torch.Size([768])
# 14      bert.encoder.layer.0.attention.output.LayerNorm.bias
# torch.Size([768])
# 15      bert.encoder.layer.0.intermediate.dense.weight  torch.Size([3072, 768])
# 16      bert.encoder.layer.0.intermediate.dense.bias    torch.Size([3072])
# 17      bert.encoder.layer.0.output.dense.weight        torch.Size([768, 3072])
# 18      bert.encoder.layer.0.output.dense.bias  torch.Size([768])
# 19      bert.encoder.layer.0.output.LayerNorm.weight    torch.Size([768])
# 20      bert.encoder.layer.0.output.LayerNorm.bias      torch.Size([768])
# 21      bert.encoder.layer.1.attention.self.query.weight        torch.Size([768,
# 768])
# 22      bert.encoder.layer.1.attention.self.query.bias  torch.Size([768])
# 23      bert.encoder.layer.1.attention.self.key.weight  torch.Size([768, 768])
# 24      bert.encoder.layer.1.attention.self.key.bias    torch.Size([768])
# 25      bert.encoder.layer.1.attention.self.value.weight        torch.Size([768,
# 768])
# 26      bert.encoder.layer.1.attention.self.value.bias  torch.Size([768])
# 27      bert.encoder.layer.1.attention.output.dense.weight      torch.Size([768,
# 768])
# 28      bert.encoder.layer.1.attention.output.dense.bias
# torch.Size([768])
# 29      bert.encoder.layer.1.attention.output.LayerNorm.weight
# torch.Size([768])
# 30      bert.encoder.layer.1.attention.output.LayerNorm.bias
# torch.Size([768])
# 31      bert.encoder.layer.1.intermediate.dense.weight  torch.Size([3072, 768])
# 32      bert.encoder.layer.1.intermediate.dense.bias    torch.Size([3072])
# 33      bert.encoder.layer.1.output.dense.weight        torch.Size([768, 3072])
# 34      bert.encoder.layer.1.output.dense.bias  torch.Size([768])
# 35      bert.encoder.layer.1.output.LayerNorm.weight    torch.Size([768])
# 36      bert.encoder.layer.1.output.LayerNorm.bias      torch.Size([768])
# 37      bert.encoder.layer.2.attention.self.query.weight        torch.Size([768,
# 768])
# 38      bert.encoder.layer.2.attention.self.query.bias  torch.Size([768])
# 39      bert.encoder.layer.2.attention.self.key.weight  torch.Size([768, 768])
# 40      bert.encoder.layer.2.attention.self.key.bias    torch.Size([768])
# 41      bert.encoder.layer.2.attention.self.value.weight        torch.Size([768,
# 768])
# 42      bert.encoder.layer.2.attention.self.value.bias  torch.Size([768])
# 43      bert.encoder.layer.2.attention.output.dense.weight      torch.Size([768,
# 768])
# 44      bert.encoder.layer.2.attention.output.dense.bias
# torch.Size([768])
# 45      bert.encoder.layer.2.attention.output.LayerNorm.weight
# torch.Size([768])
# 46      bert.encoder.layer.2.attention.output.LayerNorm.bias
# torch.Size([768])
# 47      bert.encoder.layer.2.intermediate.dense.weight  torch.Size([3072, 768])
# 48      bert.encoder.layer.2.intermediate.dense.bias    torch.Size([3072])
# 49      bert.encoder.layer.2.output.dense.weight        torch.Size([768, 3072])
# 50      bert.encoder.layer.2.output.dense.bias  torch.Size([768])
# 51      bert.encoder.layer.2.output.LayerNorm.weight    torch.Size([768])
# 52      bert.encoder.layer.2.output.LayerNorm.bias      torch.Size([768])
# 53      bert.encoder.layer.3.attention.self.query.weight        torch.Size([768,
# 768])
# 54      bert.encoder.layer.3.attention.self.query.bias  torch.Size([768])
# 55      bert.encoder.layer.3.attention.self.key.weight  torch.Size([768, 768])
# 56      bert.encoder.layer.3.attention.self.key.bias    torch.Size([768])
# 57      bert.encoder.layer.3.attention.self.value.weight        torch.Size([768,
# 768])
# 58      bert.encoder.layer.3.attention.self.value.bias  torch.Size([768])
# 59      bert.encoder.layer.3.attention.output.dense.weight      torch.Size([768,
# 768])
# 60      bert.encoder.layer.3.attention.output.dense.bias
# torch.Size([768])
# 61      bert.encoder.layer.3.attention.output.LayerNorm.weight
# torch.Size([768])
# 62      bert.encoder.layer.3.attention.output.LayerNorm.bias
# torch.Size([768])
# 63      bert.encoder.layer.3.intermediate.dense.weight  torch.Size([3072, 768])
# 64      bert.encoder.layer.3.intermediate.dense.bias    torch.Size([3072])
# 65      bert.encoder.layer.3.output.dense.weight        torch.Size([768, 3072])
# 66      bert.encoder.layer.3.output.dense.bias  torch.Size([768])
# 67      bert.encoder.layer.3.output.LayerNorm.weight    torch.Size([768])
# 68      bert.encoder.layer.3.output.LayerNorm.bias      torch.Size([768])
# 69      bert.encoder.layer.4.attention.self.query.weight        torch.Size([768,
# 768])
# 70      bert.encoder.layer.4.attention.self.query.bias  torch.Size([768])
# 71      bert.encoder.layer.4.attention.self.key.weight  torch.Size([768, 768])
# 72      bert.encoder.layer.4.attention.self.key.bias    torch.Size([768])
# 73      bert.encoder.layer.4.attention.self.value.weight        torch.Size([768,
# 768])
# 74      bert.encoder.layer.4.attention.self.value.bias  torch.Size([768])
# 75      bert.encoder.layer.4.attention.output.dense.weight      torch.Size([768,
# 768])
# 76      bert.encoder.layer.4.attention.output.dense.bias
# torch.Size([768])
# 77      bert.encoder.layer.4.attention.output.LayerNorm.weight
# torch.Size([768])
# 78      bert.encoder.layer.4.attention.output.LayerNorm.bias
# torch.Size([768])
# 79      bert.encoder.layer.4.intermediate.dense.weight  torch.Size([3072, 768])
# 80      bert.encoder.layer.4.intermediate.dense.bias    torch.Size([3072])
# 81      bert.encoder.layer.4.output.dense.weight        torch.Size([768, 3072])
# 82      bert.encoder.layer.4.output.dense.bias  torch.Size([768])
# 83      bert.encoder.layer.4.output.LayerNorm.weight    torch.Size([768])
# 84      bert.encoder.layer.4.output.LayerNorm.bias      torch.Size([768])
# 85      bert.encoder.layer.5.attention.self.query.weight        torch.Size([768,
# 768])
# 86      bert.encoder.layer.5.attention.self.query.bias  torch.Size([768])
# 87      bert.encoder.layer.5.attention.self.key.weight  torch.Size([768, 768])
# 88      bert.encoder.layer.5.attention.self.key.bias    torch.Size([768])
# 89      bert.encoder.layer.5.attention.self.value.weight        torch.Size([768,
# 768])
# 90      bert.encoder.layer.5.attention.self.value.bias  torch.Size([768])
# 91      bert.encoder.layer.5.attention.output.dense.weight      torch.Size([768,
# 768])
# 92      bert.encoder.layer.5.attention.output.dense.bias
# torch.Size([768])
# 93      bert.encoder.layer.5.attention.output.LayerNorm.weight
# torch.Size([768])
# 94      bert.encoder.layer.5.attention.output.LayerNorm.bias
# torch.Size([768])
# 95      bert.encoder.layer.5.intermediate.dense.weight  torch.Size([3072, 768])
# 96      bert.encoder.layer.5.intermediate.dense.bias    torch.Size([3072])
# 97      bert.encoder.layer.5.output.dense.weight        torch.Size([768, 3072])
# 98      bert.encoder.layer.5.output.dense.bias  torch.Size([768])
# 99      bert.encoder.layer.5.output.LayerNorm.weight    torch.Size([768])
# 100     bert.encoder.layer.5.output.LayerNorm.bias      torch.Size([768])
# 101     bert.encoder.layer.6.attention.self.query.weight        torch.Size([768,
# 768])
# 102     bert.encoder.layer.6.attention.self.query.bias  torch.Size([768])
# 103     bert.encoder.layer.6.attention.self.key.weight  torch.Size([768, 768])
# 104     bert.encoder.layer.6.attention.self.key.bias    torch.Size([768])
# 105     bert.encoder.layer.6.attention.self.value.weight        torch.Size([768,
# 768])
# 106     bert.encoder.layer.6.attention.self.value.bias  torch.Size([768])
# 107     bert.encoder.layer.6.attention.output.dense.weight      torch.Size([768,
# 768])
# 108     bert.encoder.layer.6.attention.output.dense.bias
# torch.Size([768])
# 109     bert.encoder.layer.6.attention.output.LayerNorm.weight
# torch.Size([768])
# 110     bert.encoder.layer.6.attention.output.LayerNorm.bias
# torch.Size([768])
# 111     bert.encoder.layer.6.intermediate.dense.weight  torch.Size([3072, 768])
# 112     bert.encoder.layer.6.intermediate.dense.bias    torch.Size([3072])
# 113     bert.encoder.layer.6.output.dense.weight        torch.Size([768, 3072])
# 114     bert.encoder.layer.6.output.dense.bias  torch.Size([768])
# 115     bert.encoder.layer.6.output.LayerNorm.weight    torch.Size([768])
# 116     bert.encoder.layer.6.output.LayerNorm.bias      torch.Size([768])
# 117     bert.encoder.layer.7.attention.self.query.weight        torch.Size([768,
# 768])
# 118     bert.encoder.layer.7.attention.self.query.bias  torch.Size([768])
# 119     bert.encoder.layer.7.attention.self.key.weight  torch.Size([768, 768])
# 120     bert.encoder.layer.7.attention.self.key.bias    torch.Size([768])
# 121     bert.encoder.layer.7.attention.self.value.weight        torch.Size([768,
# 768])
# 122     bert.encoder.layer.7.attention.self.value.bias  torch.Size([768])
# 123     bert.encoder.layer.7.attention.output.dense.weight      torch.Size([768,
# 768])
# 124     bert.encoder.layer.7.attention.output.dense.bias
# torch.Size([768])
# 125     bert.encoder.layer.7.attention.output.LayerNorm.weight
# torch.Size([768])
# 126     bert.encoder.layer.7.attention.output.LayerNorm.bias
# torch.Size([768])
# 127     bert.encoder.layer.7.intermediate.dense.weight  torch.Size([3072, 768])
# 128     bert.encoder.layer.7.intermediate.dense.bias    torch.Size([3072])
# 129     bert.encoder.layer.7.output.dense.weight        torch.Size([768, 3072])
# 130     bert.encoder.layer.7.output.dense.bias  torch.Size([768])
# 131     bert.encoder.layer.7.output.LayerNorm.weight    torch.Size([768])
# 132     bert.encoder.layer.7.output.LayerNorm.bias      torch.Size([768])
# 133     bert.encoder.layer.8.attention.self.query.weight        torch.Size([768,
# 768])
# 134     bert.encoder.layer.8.attention.self.query.bias  torch.Size([768])
# 135     bert.encoder.layer.8.attention.self.key.weight  torch.Size([768, 768])
# 136     bert.encoder.layer.8.attention.self.key.bias    torch.Size([768])
# 137     bert.encoder.layer.8.attention.self.value.weight        torch.Size([768,
# 768])
# 138     bert.encoder.layer.8.attention.self.value.bias  torch.Size([768])
# 139     bert.encoder.layer.8.attention.output.dense.weight      torch.Size([768,
# 768])
# 140     bert.encoder.layer.8.attention.output.dense.bias
# torch.Size([768])
# 141     bert.encoder.layer.8.attention.output.LayerNorm.weight
# torch.Size([768])
# 142     bert.encoder.layer.8.attention.output.LayerNorm.bias
# torch.Size([768])
# 143     bert.encoder.layer.8.intermediate.dense.weight  torch.Size([3072, 768])
# 144     bert.encoder.layer.8.intermediate.dense.bias    torch.Size([3072])
# 145     bert.encoder.layer.8.output.dense.weight        torch.Size([768, 3072])
# 146     bert.encoder.layer.8.output.dense.bias  torch.Size([768])
# 147     bert.encoder.layer.8.output.LayerNorm.weight    torch.Size([768])
# 148     bert.encoder.layer.8.output.LayerNorm.bias      torch.Size([768])
# 149     bert.encoder.layer.9.attention.self.query.weight        torch.Size([768,
# 768])
# 150     bert.encoder.layer.9.attention.self.query.bias  torch.Size([768])
# 151     bert.encoder.layer.9.attention.self.key.weight  torch.Size([768, 768])
# 152     bert.encoder.layer.9.attention.self.key.bias    torch.Size([768])
# 153     bert.encoder.layer.9.attention.self.value.weight        torch.Size([768,
# 768])
# 154     bert.encoder.layer.9.attention.self.value.bias  torch.Size([768])
# 155     bert.encoder.layer.9.attention.output.dense.weight      torch.Size([768,
# 768])
# 156     bert.encoder.layer.9.attention.output.dense.bias
# torch.Size([768])
# 157     bert.encoder.layer.9.attention.output.LayerNorm.weight
# torch.Size([768])
# 158     bert.encoder.layer.9.attention.output.LayerNorm.bias
# torch.Size([768])
# 159     bert.encoder.layer.9.intermediate.dense.weight  torch.Size([3072, 768])
# 160     bert.encoder.layer.9.intermediate.dense.bias    torch.Size([3072])
# 161     bert.encoder.layer.9.output.dense.weight        torch.Size([768, 3072])
# 162     bert.encoder.layer.9.output.dense.bias  torch.Size([768])
# 163     bert.encoder.layer.9.output.LayerNorm.weight    torch.Size([768])
# 164     bert.encoder.layer.9.output.LayerNorm.bias      torch.Size([768])
# 165     bert.encoder.layer.10.attention.self.query.weight       torch.Size([768,
# 768])
# 166     bert.encoder.layer.10.attention.self.query.bias torch.Size([768])
# 167     bert.encoder.layer.10.attention.self.key.weight torch.Size([768, 768])
# 168     bert.encoder.layer.10.attention.self.key.bias   torch.Size([768])
# 169     bert.encoder.layer.10.attention.self.value.weight       torch.Size([768,
# 768])
# 170     bert.encoder.layer.10.attention.self.value.bias torch.Size([768])
# 171     bert.encoder.layer.10.attention.output.dense.weight     torch.Size([768,
# 768])
# 172     bert.encoder.layer.10.attention.output.dense.bias
# torch.Size([768])
# 173     bert.encoder.layer.10.attention.output.LayerNorm.weight
# torch.Size([768])
# 174     bert.encoder.layer.10.attention.output.LayerNorm.bias
# torch.Size([768])
# 175     bert.encoder.layer.10.intermediate.dense.weight torch.Size([3072, 768])
# 176     bert.encoder.layer.10.intermediate.dense.bias   torch.Size([3072])
# 177     bert.encoder.layer.10.output.dense.weight       torch.Size([768, 3072])
# 178     bert.encoder.layer.10.output.dense.bias torch.Size([768])
# 179     bert.encoder.layer.10.output.LayerNorm.weight   torch.Size([768])
# 180     bert.encoder.layer.10.output.LayerNorm.bias     torch.Size([768])
# 181     bert.encoder.layer.11.attention.self.query.weight       torch.Size([768,
# 768])
# 182     bert.encoder.layer.11.attention.self.query.bias torch.Size([768])
# 183     bert.encoder.layer.11.attention.self.key.weight torch.Size([768, 768])
# 184     bert.encoder.layer.11.attention.self.key.bias   torch.Size([768])
# 185     bert.encoder.layer.11.attention.self.value.weight       torch.Size([768,
# 768])
# 186     bert.encoder.layer.11.attention.self.value.bias torch.Size([768])
# 187     bert.encoder.layer.11.attention.output.dense.weight     torch.Size([768,
# 768])
# 188     bert.encoder.layer.11.attention.output.dense.bias
# torch.Size([768])
# 189     bert.encoder.layer.11.attention.output.LayerNorm.weight
# torch.Size([768])
# 190     bert.encoder.layer.11.attention.output.LayerNorm.bias
# torch.Size([768])
# 191     bert.encoder.layer.11.intermediate.dense.weight torch.Size([3072, 768])
# 192     bert.encoder.layer.11.intermediate.dense.bias   torch.Size([3072])
# 193     bert.encoder.layer.11.output.dense.weight       torch.Size([768, 3072])
# 194     bert.encoder.layer.11.output.dense.bias torch.Size([768])
# 195     bert.encoder.layer.11.output.LayerNorm.weight   torch.Size([768])
# 196     bert.encoder.layer.11.output.LayerNorm.bias     torch.Size([768])
# 197     bert.pooler.dense.weight        torch.Size([768, 768])
# 198     bert.pooler.dense.bias  torch.Size([768])
# 199     classifier.weight       torch.Size([151, 768])
# 200     classifier.bias torch.Size([151])

# %% [markdown]
# #### 모델 저장 방법:
# ```python
# torch.save(pipe.model.state_dict(), "model.pt")
# ```

# %%
import torch
from pathlib import Path

def compute_size(self):  # 모델 크기를 계산하는 메소드
    """PerformanceBenchmark.compute_size() 메서드를 오버라이드"""
    state_dict = self.pipeline.model.state_dict()
    tmp_path = Path("model.pt")
    torch.save(state_dict, tmp_path)
    # 메가바이트 단위로 크기를 계산
    # Path(tmp_path).stat().st_size : 바이트 단위 크기
    size_mb = Path(tmp_path).stat().st_size / (1024 * 1024)
    # 임시 파일을 삭제
    tmp_path.unlink()
    print(f"모델 크기 (MB) - {size_mb:.2f}")
    return {"size_mb": size_mb}

PerformanceBenchmark.compute_size = compute_size

# %% [markdown]
# #### 평균 레이턴시를 측정하기 위한 `time_pipeline()` 함수 구현:
# - `time.perf_counter()` : `time.time()` 보다 정밀

# %%
from time import perf_counter

for _ in range(3):
    start_time = perf_counter()
    _ = pipe(query)
    latency = perf_counter() - start_time
    print(f"레이턴시 (ms) - {1000 * latency:.3f}")
# Out:
# 레이턴시 (ms) - 16.507
# 레이턴시 (ms) - 15.524
# 레이턴시 (ms) - 12.423

# %% [markdown]
# - 레이턴시 편차가 심하므로, 평균과 표준편차로 분석할 필요가 있다.

# %%
import numpy as np

def time_pipeline(self, query="What is the pin number for my account?"):
    """PerformanceBenchmark.time_pipeline() 메서드를 오버라이드"""
    latencies = []
    # 워밍업
    for _ in range(10):
        _ = self.pipeline(query)
    # 실행 측정
    for _ in range(100):
        start_time = perf_counter()
        _ = self.pipeline(query)
        latency = perf_counter() - start_time
        latencies.append(latency)
    # 통계 계산
    time_avg_ms = 1000 * np.mean(latencies)
    time_std_ms = 1000 * np.std(latencies)
    print(f"평균 레이턴시 (ms) - {time_avg_ms:.2f} +\- {time_std_ms:.2f}")
    return {"time_avg_ms": time_avg_ms, "time_std_ms": time_std_ms}

PerformanceBenchmark.time_pipeline = time_pipeline
# Out:
# <>:18: SyntaxWarning: invalid escape sequence '\-'
# <>:18: SyntaxWarning: invalid escape sequence '\-'
# /tmp/ipykernel_6486/3047687255.py:18: SyntaxWarning: invalid escape sequence '\-'
#   print(f"평균 레이턴시 (ms) - {time_avg_ms:.2f} +\- {time_std_ms:.2f}")

# %%
pb = PerformanceBenchmark(pipe, clinc["test"])
perf_metrics = pb.run_benchmark()
# Out:
# 모델 크기 (MB) - 418.15
# 평균 레이턴시 (ms) - 32.07 +\- 15.04
# 테스트 세트 정확도 - 0.867

# %% [markdown]
# ## 8.3 지식 정제로 모델 크기 줄이기
# - 느리고 크지만 성능이 더 높은 티처(teacher)의 동작을 모방하도록 작은 스튜던트(student) 모델을 훈련
# - 2006년 앙상블 모델을 위해 처음 소개됨
# - 2015년 신경망에 적용(Hinton et al., "Distilling the Knowledge in a Neural Network") - 어렵지 않음. 읽어 볼 것.

# %% [markdown]
# ### 8.3.1 미세 튜닝에서의 지식 정제

# %% [markdown]
# <img alt="Soft Probabilities" caption="Comparison of a hard label that is one-hot encoded (left), softmax probabilities (middle), and softened class probabilities (right)" src="https://github.com/rickiepark/nlp-with-transformers/blob/main/images/chapter08_soft-probs.png?raw=1" width="800" id="soft-probs"/>

# %% [markdown]
# <img alt="Knowledge distillation" caption="The knowledge distillation process" src="https://github.com/rickiepark/nlp-with-transformers/blob/main/images/chapter08_kd.png?raw=1" width="800" id="kd"/>

# %% [markdown]
# - 티처의 소프트 확률로 정답 레이블을 보강하여 스튜던트가 학습할 때 부가 정보를 제공한다. 예를 들어 여러 개의 의도(intent)에 높은 확률을 할당하다면 이 의도들은 특성 공간 안에서 서로 가까이 위치 한다는 신호일 가능성이 존재하고 이런 확률을 모방하도록 훈련하여 레이블만으로 얻지 못하는 지식(결정 경계에 대한 정보)까지 학습하도록 한다.
# - Dark Knowledge: 레이블 만으로는 얻지 못하는 지식(by Geoffrey Hinton)

# %% [markdown]
# ### 8.3.2 사전 훈련에서의 지식 정제

# %% [markdown]
# ### 8.3.3 지식 정제 트레이너 만들기
# #### `TrainingArguments`
# - `transformers.Trainer` 클래스와 함께 사용되며, 모델 학습의 다양한 설정을 정의한다.
# - 학습 과정에서 필요한 파라미터(예: 학습률, 배치 크기, 에포크 수 등)를 지정하고, 학습 로그, 모델 저장, 평가 전략 등을 커스터마이징할 수 있다.

# %% [markdown]
# #### 지식 정제를 구현하기 위해 `Trainer` 클래스에 속성 추가
# - `TrainingArguments`를 상속해서 몇 가지 속성 추가

# %%
from transformers import TrainingArguments

class DistillationTrainingArguments(TrainingArguments):
    def __init__(self, *args, alpha=0.5, temperature=2.0, **kwargs):
        super().__init__(*args, **kwargs)
        self.alpha = alpha
        self.temperature = temperature

# %%
from dataclasses import dataclass, field
from transformers import TrainingArguments

@dataclass
class DistillationTrainingArguments(TrainingArguments):
    alpha: float = field(
        default=0.5,
        metadata={"help": "CrossEntropy와 Distillation Loss의 가중치 비율 (0.0~1.0)"}
    )
    temperature: float = field(
        default=2.0,
        metadata={"help": "logits을 부드럽게(soften) 할 온도 (T > 1)"}
    )

# %%
import torch.nn as nn
import torch.nn.functional as F
from transformers import Trainer

class DistillationTrainer(Trainer): # 지식 정제 손실항 추가
    def __init__(self, *args, teacher_model=None, **kwargs):
        super().__init__(*args, **kwargs)
        self.teacher_model = teacher_model  # 미리 학습된 모델 (티처 모델)

    def compute_loss(self, model, inputs, return_outputs=False, num_items_in_batch=None):
        device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        inputs = {k: v.to(device) for k, v in inputs.items()}
        # Student 모델 순전파 → CrossEntropy 손실, Student 로짓 얻기
        outputs_stu = model(**inputs)
        # 스튜던트의 크로스 엔트로피 손실과 로짓을 추출합니다
        loss_ce = outputs_stu.loss
        logits_stu = outputs_stu.logits
        # 티처의 로짓을 추출합니다
        with torch.no_grad():
            outputs_tea = self.teacher_model(**inputs)
            logits_tea = outputs_tea.logits
        # 확률을 부드럽게하고 teacher 모델의 정보를 반영
        # alpha를 조절해서 라벨에 대한 정보와 teacher 정보의 비율을 조절
        loss_fct = nn.KLDivLoss(reduction="batchmean") # KL-divergence를 계산해 주는 손실 함수
        loss_kd = self.args.temperature ** 2 * loss_fct( # final loss에서 균형잡힌 계산을 맞추기 편해짐
            F.log_softmax(logits_stu / self.args.temperature, dim=-1),
            F.softmax(logits_tea / self.args.temperature, dim=-1))
        # 가중 평균된 스튜던트 손실을 반환합니다
        loss = self.args.alpha * loss_ce + (1. - self.args.alpha) * loss_kd
        return (loss, outputs_stu) if return_outputs else loss

# %% [markdown]
# ### 8.3.4 좋은 스튜던트 초기화 선택하기

# %%
from transformers import AutoTokenizer

student_ckpt = "distilbert-base-uncased"
student_tokenizer = AutoTokenizer.from_pretrained(student_ckpt)

def tokenize_text(batch):
    return student_tokenizer(batch["text"], truncation=True)

clinc_enc = clinc.map(tokenize_text, batched=True, remove_columns=["text"])
clinc_enc = clinc_enc.rename_column("intent", "labels")  # 미세튜닝할 때 Trainer는 기본적으로 labels 이름의 열을 찾는다.

# %%
from huggingface_hub import notebook_login

notebook_login()

# %%
def compute_metrics(pred): # 추적할 성능 지표
    predictions, labels = pred
    predictions = np.argmax(predictions, axis=1)
    return accuracy_score.compute(predictions=predictions, references=labels)

# %%
# batch_size = 48

# finetuned_ckpt = "distilbert-base-uncased-finetuned-clinc"
# student_training_args = DistillationTrainingArguments(
#     output_dir=finetuned_ckpt, eval_strategy = "epoch",  # correct "evaluation_strategy" to "eval_strategy"
#     num_train_epochs=5, learning_rate=2e-5,
#     per_device_train_batch_size=batch_size,
#     per_device_eval_batch_size=batch_size, alpha=1, weight_decay=0.01,
#     push_to_hub=True)

# %%
# This cell was used when above cell raised an error
batch_size = 48
finetuned_ckpt = "distilbert-base-uncased-finetuned-clinc"
# alpha를 1로 해서 모델 튜닝 시작
student_training_args = DistillationTrainingArguments(
    # output_dir="dummy_dir",
    output_dir=finetuned_ckpt,
    eval_strategy="epoch",
    save_strategy="no",
    report_to="none",   # ← WandB, TensorBoard 등 모든 로깅 끔
    num_train_epochs=5,
    learning_rate=2e-5,
    per_device_train_batch_size=batch_size,
    per_device_eval_batch_size=batch_size,
    alpha=1.0,
    weight_decay=0.01,
    # push_to_hub=True,
    push_to_hub=False,
)

# %%
student_training_args.logging_steps = len(clinc_enc['train']) // batch_size
student_training_args.disable_tqdm = False
student_training_args.save_steps = 1e9
# 트랜스포머 4.23.0 버전부터 로깅 수준을 문자열로 지정해야 합니다.
# student_training_args.log_level = 40
student_training_args.log_level = 'error'

# %%
# %env TOKENIZERS_PARALLELISM=false
# Out:
# env: TOKENIZERS_PARALLELISM=false

# %%
id2label = pipe.model.config.id2label # 의도
label2id = pipe.model.config.label2id # 라벨

# %%
from transformers import AutoConfig

num_labels = intents.num_classes  # 모델이 기대해야할 클래스 갯수 설정
student_config = (AutoConfig
                  .from_pretrained(student_ckpt, num_labels=num_labels,
                                   id2label=id2label, label2id=label2id))

# %%
import torch
from transformers import AutoModelForSequenceClassification

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# 위에서 설정한 것들을 아래 AutoModelForSequenceClassification 클래스의 from_pretrained 함수에 전달
def student_init(): # 트레이너로 여러 번 실행할 거라서 모델 초기화 함수 필요
    return (AutoModelForSequenceClassification
            .from_pretrained(student_ckpt, config=student_config).to(device))

# %%
teacher_ckpt = "transformersbook/bert-base-uncased-finetuned-clinc"
teacher_model = (AutoModelForSequenceClassification
                 .from_pretrained(teacher_ckpt, num_labels=num_labels)
                 .to(device))
# Out:
# Loading weights:   0%|          | 0/201 [00:00<?, ?it/s]

# %%
distilbert_trainer = DistillationTrainer(model_init=student_init,
    teacher_model=teacher_model, args=student_training_args,
    train_dataset=clinc_enc['train'], eval_dataset=clinc_enc['validation'],
    compute_metrics=compute_metrics, processing_class=student_tokenizer)

distilbert_trainer.train()
# Out:
# Loading weights:   0%|          | 0/100 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/100 [00:00<?, ?it/s]
#     <div>
#
#       <progress value='1590' max='1590' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1590/1590 04:27, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>4.329964</td>
#       <td>3.339388</td>
#       <td>0.732258</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.689079</td>
#       <td>1.929997</td>
#       <td>0.845806</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.603731</td>
#       <td>1.202481</td>
#       <td>0.896774</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.056068</td>
#       <td>0.895425</td>
#       <td>0.911290</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.833277</td>
#       <td>0.806061</td>
#       <td>0.916129</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=1590, training_loss=2.0983257689565984, metrics={'train_runtime': 268.1948, 'train_samples_per_second': 284.308, 'train_steps_per_second': 5.929, 'total_flos': 414689637990180.0, 'train_loss': 2.0983257689565984, 'epoch': 5.0})

# %%
distilbert_trainer.push_to_hub("Training completed!")
# Out:
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Processing Files (0 / 0)      : |          |  0.00B /  0.00B
# New Data Upload               : |          |  0.00B /  0.00B
#   ...d-clinc/training_args.bin: 100%|##########| 5.33kB / 5.33kB
#   ...d-clinc/model.safetensors:  78%|#######7  |  208MB /  268MB
# CommitInfo(commit_url='https://huggingface.co/Jooooqq/distilbert-base-uncased-finetuned-clinc/commit/fde8e74f7e512bc7ce7642191bfeb08e176af43c', commit_message='Training completed!', commit_description='', oid='fde8e74f7e512bc7ce7642191bfeb08e176af43c', pr_url=None, repo_url=RepoUrl('https://huggingface.co/Jooooqq/distilbert-base-uncased-finetuned-clinc', endpoint='https://huggingface.co', repo_type='model', repo_id='Jooooqq/distilbert-base-uncased-finetuned-clinc'), pr_revision=None, pr_num=None)

# %%
# `kikim6114`를 자신의 허브 사용자 이름으로 바꾸세요.
finetuned_ckpt = "Jooooqq/distilbert-base-uncased-finetuned-clinc"
pipe = pipeline("text-classification", model=finetuned_ckpt)
# Out:
# Loading weights:   0%|          | 0/104 [00:00<?, ?it/s]
# tokenizer.json:   0%|          | 0.00/711k [00:00<?, ?B/s]

# %%
optim_type = "DistilBERT"
pb = PerformanceBenchmark(pipe, clinc["test"], optim_type=optim_type)
perf_metrics.update(pb.run_benchmark())
# Out:
# 모델 크기 (MB) - 255.88
# 평균 레이턴시 (ms) - 5.25 +\- 0.74
# 테스트 세트 정확도 - 0.855

# %%
import pandas as pd
import matplotlib.pyplot as plt
def plot_metrics(perf_metrics, current_optim_type):
    df = pd.DataFrame.from_dict(perf_metrics, orient='index')

    for idx in df.index:
        df_opt = df.loc[idx]
        # 현재 최적화 방법을 점선으로 그립니다
        if idx == current_optim_type:
            plt.scatter(df_opt["time_avg_ms"], df_opt["accuracy"] * 100,
                        alpha=0.5, s=df_opt["size_mb"], label=idx,
                        marker='$\u25CC$')
        else:
            plt.scatter(df_opt["time_avg_ms"], df_opt["accuracy"] * 100,
                        s=df_opt["size_mb"], label=idx, alpha=0.5)

    legend = plt.legend(bbox_to_anchor=(1,1))
    for handle in legend.legend_handles:
        handle.set_sizes([20])

    plt.ylim(80,90)
    # 가장 느린 모델을 사용해 x 축 범위를 정합니다
    xlim = int(perf_metrics["BERT baseline"]["time_avg_ms"] + 3)
    plt.xlim(1, xlim)
    plt.ylabel("Accuracy (%)")
    plt.xlabel("Average latency (ms)")
    plt.show()

plot_metrics(perf_metrics, optim_type)

# %% [markdown]
# ### 8.3.5 옵투나로 좋은 하이퍼파라미터 찾기
# - 좋은 $\alpha$ 와 $\mathit{T}$ 값을 찾기 위해 2D 하이퍼파라미터 공간에서 그리드 서치(grid search)를 수행할 수 있다.
# - 최적화 프레임워크 Optuna를 사용하는 것이 더 좋은 방법이다.
# - Optuna는 search 문제를 여러 시도를 통해 최적화시킬 목적 함수로 표현한다.

# %% [markdown]
# ##### 로젠브록의 바나나 함수 최소화:
# $$f(x, y)=(1-x)^2+100(y-x^2)^2$$

# %%
# 두 변수를 가진 로젠브록(Rosenbrock) 함수 그래프
import matplotlib.pyplot as plt
import numpy as np

def f(x, y):
    return (1-x)**2+100*(y-x**2)**2

X, Y = np.meshgrid(np.linspace(-2, 2, 250), np.linspace(-1, 3, 250))
Z = f(X,Y)
_, ax = plt.subplots()
ax.plot([1], [1], 'x', mew=3, markersize=10, color="red")
ax.contourf(X, Y, Z, np.logspace(-1, 3, 30), cmap='viridis', extend="both")
ax.set_xlim(-1.3, 1.3)
ax.set_ylim(-0.9, 1.7)
plt.show()

# %% [markdown]
# 이 바나나 함수는 점 $(1,1)$에서 최솟값을 가지며, 골짜기 영역을 찾는 것은 쉽지만 최솟값으로 수렴하기는 어렵다는 특징을 갖는다.

# %%
def objective(trial):
    x = trial.suggest_float("x", -2, 2)
    y = trial.suggest_float("y", -2, 2)
    return (1 - x) ** 2 + 100 * (y - x ** 2) ** 2

# %% [markdown]
# - `suggest_int`와 `suggest_catagorical` 도 제공

# %%
import optuna

study = optuna.create_study()
study.optimize(objective, n_trials=1000)
# Out:
# [I 2026-06-09 12:10:53,818] A new study created in memory with name: no-name-603481a2-7b26-45cc-928e-e40a7c436b3b
. Best is trial 819 with value: 0.0022212673685338322.
# [I 2026-06-09 12:11:02,906] Trial 991 finished with value: 1.2897277793230177 and parameters: {'x': 0.9217678528898896, 'y': 0.7363595708618257}. Best is trial 819 with value: 0.0022212673685338322.
# [I 2026-06-09 12:11:02,920] Trial 992 finished with value: 0.001755803701087605 and parameters: {'x': 0.9924082275798004, 'y': 0.9807532059272808}. Best is trial 992 with value: 0.001755803701087605.
# [I 2026-06-09 12:11:02,934] Trial 993 finished with value: 11.02306761913476 and parameters: {'x': 1.1837732164811667, 'y': 1.0698179718903336}. Best is trial 992 with value: 0.001755803701087605.
# [I 2026-06-09 12:11:02,947] Trial 994 finished with value: 0.25375051466951065 and parameters: {'x': 1.0634865788195846, 'y': 1.180975692381182}. Best is trial 992 with value: 0.001755803701087605.
# [I 2026-06-09 12:11:02,959] Trial 995 finished with value: 23.26545225869255 and parameters: {'x': 1.2221687175139329, 'y': 1.0118655601976994}. Best is trial 992 with value: 0.001755803701087605.
# [I 2026-06-09 12:11:02,972] Trial 996 finished with value: 0.06039774524128199 and parameters: {'x': 1.0021617078086889, 'y': 0.9797530866121416}. Best is trial 992 with value: 0.001755803701087605.
# [I 2026-06-09 12:11:02,984] Trial 997 finished with value: 78.50046562880652 and parameters: {'x': -0.510905597704404, 'y': 1.134051619286014}. Best is trial 992 with value: 0.001755803701087605.
# [I 2026-06-09 12:11:02,995] Trial 998 finished with value: 11.376267330647726 and parameters: {'x': 1.1285713369435908, 'y': 0.936631177038818}. Best is trial 992 with value: 0.001755803701087605.
# [I 2026-06-09 12:11:03,009] Trial 999 finished with value: 0.020778203144417622 and parameters: {'x': 1.0167610311828104, 'y': 1.0481198625477048}. Best is trial 992 with value: 0.001755803701087605.

# %%
study.best_params
# Out:
# {'x': 0.9924082275798004, 'y': 0.9807532059272808}

# %% [markdown]
# #### 트랜스포머스에서 옵투나 사용 순서
# 1) 최적화 하려는 하이퍼파라미터 공간을 정의
# 2) Trainer의 hyperparameter_search() 메서드에 시도 횟수, 최적화 방향, 하이퍼라라미터 검색 공간을 전달
# 3) BestRun 반환됨

# %%
def hp_space(trial):
    return {"num_train_epochs": trial.suggest_int("num_train_epochs", 5, 10),
        "alpha": trial.suggest_float("alpha", 0, 1),
        "temperature": trial.suggest_int("temperature", 2, 20)}

# %%
best_run = distilbert_trainer.hyperparameter_search(
    n_trials=20, direction="maximize", hp_space=hp_space)
# Out:
# [I 2026-06-09 12:11:05,665] A new study created in memory with name: no-name-4f63ecbb-c98d-4efd-9ad8-3de01776ae32
# Loading weights:   0%|          | 0/100 [00:00<?, ?it/s]
#     <div>
#
#       <progress value='1590' max='1590' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1590/1590 04:32, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.991383</td>
#       <td>0.664707</td>
#       <td>0.711613</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.531902</td>
#       <td>0.365369</td>
#       <td>0.867097</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.333424</td>
#       <td>0.252463</td>
#       <td>0.915806</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.252266</td>
#       <td>0.208220</td>
#       <td>0.926129</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.221441</td>
#       <td>0.195707</td>
#       <td>0.925806</td>
#     </tr>
#   </tbody>
# </table><p>
# [I 2026-06-09 12:15:39,338] Trial 0 finished with value: 0.9258064516129032 and parameters: {'num_train_epochs': 5, 'alpha': 0.15036142716501288, 'temperature': 13}. Best is trial 0 with value: 0.9258064516129032.
# Loading weights:   0%|          | 0/100 [00:00<?, ?it/s]
#     <div>
#
#       <progress value='3180' max='3180' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [3180/3180 08:54, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>3.715393</td>
#       <td>2.798092</td>
#       <td>0.737419</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.161516</td>
#       <td>1.433684</td>
#       <td>0.865161</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1
style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 636/2226 01:47 < 04:28, 5.93 it/s, Epoch 2/7]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>2.982518</td>
#       <td>2.259421</td>
#       <td>0.733871</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.794219</td>
#       <td>1.252002</td>
#       <td>0.857742</td>
#     </tr>
#   </tbody>
# </table><p>
# [I 2026-06-09 13:15:36,322] Trial 17 pruned.
# Loading weights:   0%|          | 0/100 [00:00<?, ?it/s]
#     <div>
#
#       <progress value='1908' max='2862' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1908/2862 05:21 < 02:40, 5.94 it/s, Epoch 6/9]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>2.049054</td>
#       <td>1.491857</td>
#       <td>0.737097</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.172112</td>
#       <td>0.797309</td>
#       <td>0.871935</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.649577</td>
#       <td>0.467510</td>
#       <td>0.918065</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.393649</td>
#       <td>0.325040</td>
#       <td>0.930968</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.273602</td>
#       <td>0.262199</td>
#       <td>0.937742</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.217108</td>
#       <td>0.237412</td>
#       <td>0.939677</td>
#     </tr>
#   </tbody>
# </table><p>
# [I 2026-06-09 13:20:58,121] Trial 18 pruned.
# Loading weights:   0%|          | 0/100 [00:00<?, ?it/s]
#     <div>
#
#       <progress value='636' max='1908' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 636/1908 01:46 < 03:34, 5.93 it/s, Epoch 2/6]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>3.760275</td>
#       <td>2.877838</td>
#       <td>0.732258</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.293704</td>
#       <td>1.612793</td>
#       <td>0.853226</td>
#     </tr>
#   </tbody>
# </table><p>
# [I 2026-06-09 13:22:45,860] Trial 19 pruned.

# %%
print(best_run)
# Out:
# BestRun(run_id='1', objective=0.9451612903225807,
# hyperparameters={'num_train_epochs': 10, 'alpha': 0.8469318670724281,
# 'temperature': 11}, run_summary=None)

# %%
for k,v in best_run.hyperparameters.items():
    setattr(student_training_args, k, v)

# 정제된 모델을 저장할 새로운 저장소를 정의합니다
distilled_ckpt = "distilbert-base-uncased-distilled-clinc"
student_training_args.output_dir = distilled_ckpt

# 최적의 매개변수로 새로운 Trainer를 만듭니다
distil_trainer = DistillationTrainer(model_init=student_init,
    teacher_model=teacher_model, args=student_training_args,
    train_dataset=clinc_enc['train'], eval_dataset=clinc_enc['validation'],
    compute_metrics=compute_metrics,processing_class=student_tokenizer)

distil_trainer.train();
# Out:
# Loading weights:   0%|          | 0/100 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/100 [00:00<?, ?it/s]
#     <div>
#
#       <progress value='3180' max='3180' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [3180/3180 08:54, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>3.715393</td>
#       <td>2.798092</td>
#       <td>0.737419</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.161516</td>
#       <td>1.433684</td>
#       <td>0.865161</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.099955</td>
#       <td>0.757373</td>
#       <td>0.913871</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.578297</td>
#       <td>0.483895</td>
#       <td>0.930323</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.345940</td>
#       <td>0.369269</td>
#       <td>0.939677</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.237195</td>
#       <td>0.328175</td>
#       <td>0.941935</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.183183</td>
#       <td>0.302012</td>
#       <td>0.943548</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.153453</td>
#       <td>0.288754</td>
#       <td>0.945484</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.137965</td>
#       <td>0.282633</td>
#       <td>0.947097</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.130531</td>
#       <td>0.281287</td>
#       <td>0.945161</td>
#     </tr>
#   </tbody>
# </table><p>

# %%
distil_trainer.push_to_hub("Training complete")
# Out:
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Processing Files (0 / 0)      : |          |  0.00B /  0.00B
# New Data Upload               : |          |  0.00B /  0.00B
#   ...d-clinc/model.safetensors:   0%|          | 1.15MB /  268MB
#   ...d-clinc/training_args.bin: 100%|##########| 5.33kB / 5.33kB
# CommitInfo(commit_url='https://huggingface.co/Jooooqq/distilbert-base-uncased-distilled-clinc/commit/4d5710092d527d354f8cb76c880cdc4dfb2afcad', commit_message='Training complete', commit_description='', oid='4d5710092d527d354f8cb76c880cdc4dfb2afcad', pr_url=None, repo_url=RepoUrl('https://huggingface.co/Jooooqq/distilbert-base-uncased-distilled-clinc', endpoint='https://huggingface.co', repo_type='model', repo_id='Jooooqq/distilbert-base-uncased-distilled-clinc'), pr_revision=None, pr_num=None)

# %% [markdown]
# ### 정제 모델 벤치마크 수행하기

# %%
# `kikim6114`를 자신의 깃허브 사용자 이름으로 바꾸세요.
distilled_ckpt = "Jooooqq/distilbert-base-uncased-distilled-clinc"
pipe = pipeline("text-classification", model=distilled_ckpt)
optim_type = "Distillation"
pb = PerformanceBenchmark(pipe, clinc["test"], optim_type=optim_type)
perf_metrics.update(pb.run_benchmark())
# Out:
# config.json:   0%|          | 0.00/8.23k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/104 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/351 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/711k [00:00<?, ?B/s]
# 모델 크기 (MB) - 255.88
# 평균 레이턴시 (ms) - 4.52 +\- 0.78
# 테스트 세트 정확도 - 0.885

# %%
plot_metrics(perf_metrics, optim_type)

# %% [markdown]
# ## 8.4 양자화로 모델 속도 높이기

# %% [markdown]
# ### 사이드바: 부동 소수점 숫자 vs 고정 소수점 숫자
# - 고정소수점: $123.456$
# - 부동소수점: $1.23456 \times 10^2=0.00123456 \times 10^5=12.3456 \times 10$ ... 등
# - 가중치, 활성화, 그래디언트 등은 FP32 또는 FP16과 FP32를 혼합해 표현한다.
# #### 고정 소수점

# %% [markdown]
# ### End sidebar

# %% [markdown]
# <img alt="Mapping floating-point numbers to 8-bit integers" width="800" caption="Quantizing floating-point numbers as unsigned 8-bit integers (courtesy of Manas Sahni)" src="https://github.com/kikim6114/nlp2026-transformers/blob/main/images/chapter08_fp32-to-int8.png?raw=1" id="fp32toint8"/> <br>
# [그림 8-6] 부동소수점 숫자를 부호 없는 8비트 정수로 양자화하기(Manas Sahni 제공)

# %% [markdown]
# #### 양자화의 기본 원리:
# 부동소수점 숫자 $f$를 원래 범위 $[f_{max}, f_{min}]$에서 고정소수점 숫자 $q$로 표현된 작은 범위 $[q_{max}, q_{min}]$으로 매핑하고 모든 값을 이 구간에 선형적으로 분포시킨다.
# $$f=\left(\frac{f_{max}-f_{min}}{q_{max}-q_{min}}\right)(q-Z)=S(q-Z)$$
# 여기서,
#   - $S$: scale factor
#   - $Z$: $q$와 동일한 타입으로, $f=0$ 을 양자화한 값으로서 영점(zero point)라고 함.

# %%
import matplotlib.pyplot as plt

state_dict = pipe.model.state_dict()
weights = state_dict["distilbert.transformer.layer.0.attention.out_lin.weight"]
plt.hist(weights.flatten().cpu().numpy(), bins=250, range=(-0.3,0.3), edgecolor="C0")
plt.show()

# %% [markdown]
# 8-bit 정수로 압축한다면,
# $[q_{max}, q_{min}]=[-128, 127]$

# %%
zero_point = 0
scale = (weights.max() - weights.min()) / (127 - (-128))

# %% [markdown]
# 양자화된 텐서 계산:
# $$q=\frac{f}{S}+Z$$
# 를 계산하고, 범위 밖의 값을 클리핑하고, 가장 가까운 정수로 반올림하고, `Tensor.char()` 함수를 사용해 `torch.int8` 타입으로 표현.

# %%
(weights / scale + zero_point).clamp(-128, 127).round().char()
# Out:
# tensor([[ -5,  -8,   0,  ...,  -6,  -4,   8],
#         [  9,   2,   1,  ...,  -4,   7,   0],
#         [ -9,  -5,   6,  ...,   0,   6,  -4],
#         ...,
#         [  6,   0,  13,  ...,   0,   6,  -1],
#         [  0,  -3, -12,  ...,  12,  -7, -13],
#         [-12,  -1,  -9,  ...,   8,   2,  -1]], device='cuda:0',
#        dtype=torch.int8)

# %% [markdown]
# #### 파이토치의 함수 사용한 양자화:

# %%
from torch import quantize_per_tensor

dtype = torch.qint8
quantized_weights = quantize_per_tensor(weights, scale.item(), int(zero_point), dtype)
quantized_weights.int_repr()
# Out:
# tensor([[ -5,  -8,   0,  ...,  -6,  -4,   8],
#         [  9,   2,   1,  ...,  -4,   7,   0],
#         [ -9,  -5,   6,  ...,   0,   6,  -4],
#         ...,
#         [  6,   0,  13,  ...,   0,   6,  -1],
#         [  0,  -3, -12,  ...,  12,  -7, -13],
#         [-12,  -1,  -9,  ...,   8,   2,  -1]], device='cuda:0',
#        dtype=torch.int8)

# %%
# 트랜스포머 가중치에서 양자화 효과
from mpl_toolkits.axes_grid1.inset_locator import zoomed_inset_axes,mark_inset

# 히스토그램 그리기
fig, ax = plt.subplots()
ax.hist(quantized_weights.dequantize().flatten().cpu().numpy(),
         bins=250, range=(-0.3,0.3), edgecolor="C0");
# 확대 그림 만들기
axins = zoomed_inset_axes(ax, 5, loc='upper right')
axins.hist(quantized_weights.dequantize().flatten().cpu().numpy(),
         bins=250, range=(-0.3,0.3));
x1, x2, y1, y2 = 0.05, 0.1, 500, 2500
axins.set_xlim(x1, x2)
axins.set_ylim(y1, y2)
axins.axes.xaxis.set_visible(False)
axins.axes.yaxis.set_visible(False)
mark_inset(ax, axins, loc1=2, loc2=4, fc="none", ec="0.5")
plt.show()

# %%
# %%timeit
weights @ weights  # FP32 @ FP32
# Out:
# 220 µs ± 992 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
weights_cpu = weights.cpu()

# %%
# %%timeit
weights_cpu @ weights_cpu  # FP32 @ FP32
# Out:
# 7.87 ms ± 1.28 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# ##### 양자화된 텐서 곱

# %%
# QFunctional은 PyTorch 최신 버전에서 제거됨 → torch.ops.quantized 사용
# Move the quantized tensor to CPU
quantized_weights_cpu = quantized_weights.cpu()

# %%
# %%timeit
torch.ops.quantized.mul(quantized_weights_cpu, quantized_weights_cpu, scale=1.0, zero_point=0)
# Out:
# 201 µs ± 9.99 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
1.45*1000/55.5
# Out:
# 26.126126126126128

# %% [markdown]
# 가중치 텐서와 양자화된 텐서의 저장 크기 비교

# %%
import sys

sys.getsizeof(weights.untyped_storage()) / sys.getsizeof(quantized_weights.untyped_storage())
# Out:
# 3.999715196311114

# %% [markdown]
# 트랜스포머의 실제 압축 비율은 어떤 층을 양자화하는지에 따라 달라지며, 보통 선형 층만 양자화 한다. 모든 연산에서 정밀도를 바꾸면 모델 성능에 나쁜 영향을 주므로 주의해야 한다.
# #### 신경망에서의 양자화 방법
# 1) 동적 양자화:
#   - 훈련 중에는 적용하지 않으며, 가중치와 활성화값이 추론 직전에 (동적으로) INT8으로 변환
#   - 가장 간단한 방법
#   - 활성화를 메모리에 읽고 쓸 때 부동소수점 형식을 사용하므로 정밀도 변환이 병목이 될 수 있다.
#
# 2) 정적 양자화:
#   - 양자화 체계를 사전에 계산해 양자화 변환 부담을 피하는 방법
#   - 추론에 앞서 대표적 샘플 데이터에서 활성화 패턴을 관찰하여 수행
#   - 대표적 샘플을 찾는 방법이 어려움
#   - 훈련과 추론 과정애서 정밀도 차이로 인한 모델 성능 저하 문제 해결이 어려움
#
# 3) 양자화를 고려한 훈련:
#   - 가짜로 FP32 값을 양자화해 훈련 중에 양자화 효과를 시뮬레이션
#   - 훈련 중 FP32를 반올림하여 양자화 효과를 흉내낸다.
#   - 정방향/역방향 패스 모두에 적용됨 정적/동적 양자화를 모두 사용해 모델 성능을 높인다.
#
# #### 양자화 방법의 선택 기준
# - 추론 시 트랜스포머의 주요 병목 지점은 가중치 관련 연산 및 메모리 대역폭
# - 따라서 트랜스포머 기반 NLP 모델에서는 동적 양자화가 최상의 선택
# - 보다 작은 컴퓨터 비전 모델에서는 정적 양자화
# - 병목 현상이 너무 크면 양자화를 고려한 훈련을 사용

# %% [markdown]
# #### PyTorch에서 동적 양자화

# %%
from torch.quantization import quantize_dynamic

# `kikim6114`를 자신의 허브 사용자 이름으로 바꾸세요.
model_ckpt = "Jooooqq/distilbert-base-uncased-distilled-clinc"
tokenizer = AutoTokenizer.from_pretrained(model_ckpt)
model = (AutoModelForSequenceClassification
         .from_pretrained(model_ckpt).to("cpu"))

model_quantized = quantize_dynamic(model, {nn.Linear}, dtype=torch.qint8)
# Out:
# Loading weights:   0%|          | 0/104 [00:00<?, ?it/s]
# /tmp/ipykernel_6486/1130554713.py:9: DeprecationWarning: torch.ao.quantization is deprecated and will be removed in 2.10.
# For migrations of users:
# 1. Eager mode quantization (torch.ao.quantization.quantize, torch.ao.quantization.quantize_dynamic), please migrate to use torchao eager mode quantize_ API instead
# 2. FX graph mode quantization (torch.ao.quantization.quantize_fx.prepare_fx,torch.ao.quantization.quantize_fx.convert_fx, please migrate to use torchao pt2e quantization API instead (prepare_pt2e, convert_pt2e)
# 3. pt2e quantization has been migrated to torchao (https://github.com/pytorch/ao/tree/main/torchao/quantization/pt2e)
# see https://github.com/pytorch/ao/issues/2259 for more details
#   model_quantized = quantize_dynamic(model, {nn.Linear}, dtype=torch.qint8)

# %% [markdown]
# ### 8.5 양자화된 모델의 벤치마크 수행하기

# %%
pipe = pipeline("text-classification", model=model_quantized,
                tokenizer=tokenizer, device="cpu")
optim_type = "Distillation + quantization"
pb = PerformanceBenchmark(pipe, clinc["test"], optim_type=optim_type)
perf_metrics.update(pb.run_benchmark())
# Out:
# 모델 크기 (MB) - 132.39
# 평균 레이턴시 (ms) - 13.77 +\- 1.94
# 테스트 세트 정확도 - 0.895

# %%
plot_metrics(perf_metrics, optim_type)

# %% [markdown]
# ## 8.6 ONNX와 ONNX 런타임으로 추론 최적화하기

# %% [markdown]
# #### ONNX(Open Neural Network Exchange) 란?
#
# - 파이토치, 텐서플로 등 다양한 프레임워크에서 딥러닝 모델을 나타내기 위해 공통 연산자와 공통 파일 포맷을 정의하는 공개 표준.
# - ONNX는 모델을 중간 계층 형식으로 변환하고 모델을 실행하는 데 필요한 라이브러리를 제공한다.
# - 파이토치 모델 $\leftrightarrow$ ONNX $\leftrightarrow$ 텐서플로 모델 임포트 가능
#
# #### ONNX Runtime 이란?
#
# - ONNX 모델을 실행하기 위한 엔진으로서, ONNX 런타임은 빠른 추론을 위한 최적화된 커널을 사용한다.
# - CPU, GPU 및 딥러닝 가속기(DNNL, NNAPI, OpenVINO)를 지원.
#
# #### ONNX가 만들어 내는 계산 그래프
# - 모델을 ONNX 포맷으로 내보내면 ONNX의 연산자를 사용해 신경망을 통과하는 데이터의 흐름을 표현하기 위해 계산그래프(중간 표현이라고도 함)를 만든다.

# %% [markdown]
# <img alt="Example ONNX graph" width="500" caption="A section of the ONNX graph for BERT-base, visualized in Netron" src="https://github.com/kikim6114/nlp2026-transformers/blob/main/images/chapter08_bert-onnx.png?raw=1" id="bert-onnx"/>
# <br>
# [그림 8-8] Netron으로 시각화한 BERT 기반 모델에 대한 ONNX 그래프의 한 섹션

# %% [markdown]
# #### ONNX 런타임
# - ONNX 런타임(ORT)는 연산자 융합 상수 폴딩 같은 ONNX 그래프 최적화 도구를 제공
# - 여러 종류의 하드웨어에서 모델을 실행하도록 실행 공급자(execution provide)를 위한 인터페이스를 정의하며 이것은 강력한 추상화이다.

# %% [markdown]
# <img alt="Architecture of the ONNX and ONNX Runtime ecosystem" width="500" caption="Architecture of the ONNX and ONNX Runtime ecosystem (courtesy of the ONNX Runtime team)" src="https://github.com/kikim6114/nlp2026-transformers/blob/main/images/chapter08_onnx-ort.png?raw=1" id="onnx-ort"/> <br>
# [그림 8-9] ONNX와 ONNX 런타임 생태계의 아키텍처(ONNX 런타임 팀 제공)

# %% [markdown]
# #### ONNX 실행을 위한 `convert_graph_to_onnx.convert()` 함수가 처리하는 일:
# 1) 하나의 파이프라인으로 모델을 초기화
# 2) ONNX가 계산 그래프를 기록하도록 플레이스홀더 입력으로 파이프라인을 실행
# 3) 동적 시퀀스 길이를 처리하기 위해 동적인 축을 정의
# 4) 네트워크 파라미터와 함께 이 그래프를 저장

# %% [markdown]
# #### ONNX를 위한 OpenMP 환경 변수를 지정:

# %%
# !pip install onnx
# !pip install onnxruntime
# Out:
# Requirement already satisfied: onnx in /usr/local/lib/python3.12/dist-packages (1.21.0)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.12/dist-packages (from onnx) (2.0.2)
# Requirement already satisfied: protobuf>=4.25.1 in /usr/local/lib/python3.12/dist-packages (from onnx) (5.29.6)
# Requirement already satisfied: typing_extensions>=4.7.1 in /usr/local/lib/python3.12/dist-packages (from onnx) (4.15.0)
# Requirement already satisfied: ml_dtypes>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from onnx) (0.5.4)
# Requirement already satisfied: onnxruntime in /usr/local/lib/python3.12/dist-packages (1.26.0)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.12/dist-packages (from onnxruntime) (25.12.19)
# Requirement already satisfied: numpy>=1.21.6 in /usr/local/lib/python3.12/dist-packages (from onnxruntime) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from onnxruntime) (26.2)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from onnxruntime) (5.29.6)

# %%
import os
from psutil import cpu_count
# from transformers import AutoModelForSequenceClassification, AutoTokenizer # 임시로 작성
# from pathlib import Path

os.environ["OMP_NUM_THREADS"] = f"{cpu_count()}"
os.environ["OMP_WAIT_POLICY"] = "ACTIVE"

# %%
# transformers >= 4.30부터 convert_graph_to_onnx 제거됨
# → optimum 라이브러리 또는 torch.onnx.export() 사용
# !pip install "optimum[exporters]"

from optimum.exporters.onnx import main_export

# "kikim6114"를 자신의 허브 사용자 이름으로 바꾸세요.
model_ckpt = "Jooooqq/distilbert-base-uncased-distilled-clinc"
tokenizer = AutoTokenizer.from_pretrained(model_ckpt)
onnx_model_path = Path("onnx/model.onnx")
onnx_model_path.parent.mkdir(parents=True, exist_ok=True)

main_export(
    model_name_or_path=model_ckpt,
    output=onnx_model_path.parent,
    task="text-classification",
    opset=12,
)
# Out:
# Collecting optimum
#   Downloading optimum-2.1.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: transformers>=4.29 in /usr/local/lib/python3.12/dist-packages (from optimum) (5.9.0)
# Requirement already satisfied: torch>=1.11 in /usr/local/lib/python3.12/dist-packages (from optimum) (2.11.0+cu128)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from optimum) (26.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from optimum) (2.0.2)
# Requirement already satisfied: huggingface_hub>=0.8.0 in /usr/local/lib/python3.12/dist-packages (from optimum) (1.18.0)
# Requirement already satisfied: click>=8.4.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.8.0->optimum) (8.4.1)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.8.0->optimum) (3.29.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.8.0->optimum) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.8.0->optimum) (1.5.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.8.0->optimum) (0.28.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.8.0->optimum) (6.0.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.8.0->optimum) (4.67.3)
# Requirement already satisfied: typer<0.26.0,>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.8.0->optimum) (0.25.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.8.0->optimum) (4.15.0)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->optimum) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->optimum) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->optimum) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->optimum) (3.1.6)
# Requirement already satisfied: cuda-toolkit==12.8.1 in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.11->optimum) (12.8.1)
# Requirement already satisfied: cuda-bindings<13,>=12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->optimum) (12.9.7)
# Requirement already satisfied: nvidia-cudnn-cu12==9.19.0.56 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->optimum) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->optimum) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.28.9 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->optimum) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->optimum) (3.4.5)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->optimum) (3.6.0)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.11->optimum) (12.8.4.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.11->optimum) (12.8.90)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.11->optimum) (11.3.3.83)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.11->optimum) (1.13.1.3)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.11->optimum) (12.8.90)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.11->optimum) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.11->optimum) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.11->optimum) (12.5.8.93)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.11->optimum) (12.8.93)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.11->optimum) (12.8.93)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.11->optimum) (12.8.90)
# Requirement already satisfied: regex>=2025.10.22 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.29->optimum) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.29->optimum) (0.22.2)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.29->optimum) (0.7.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings<13,>=12.9.4->torch>=1.11->optimum) (1.5.5)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub>=0.8.0->optimum) (4.13.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub>=0.8.0->optimum) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub>=0.8.0->optimum) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub>=0.8.0->optimum) (3.18)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface_hub>=0.8.0->optimum) (0.16.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.11->optimum) (1.3.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<0.26.0,>=0.20.0->huggingface_hub>=0.8.0->optimum) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /usr/local/lib/python3.12/dist-packages (from typer<0.26.0,>=0.20.0->huggingface_hub>=0.8.0->optimum) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer<0.26.0,>=0.20.0->huggingface_hub>=0.8.0->optimum) (0.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.11->optimum) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface_hub>=0.8.0->optimum) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface_hub>=0.8.0->optimum) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface_hub>=0.8.0->optimum) (0.1.2)
# Downloading optimum-2.1.0-py3-none-any.whl (161 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.2/161.2 kB 6.3 MB/s eta 0:00:00
# Installing collected packages: optimum
# Successfully installed optimum-2.1.0
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_6486/1340582003.py in <cell line: 0>()
#       3 get_ipython().system('pip install optimum')
#       4
# ----> 5 from optimum.exporters.onnx import main_export
#       6
#       7 # "kikim6114"를 자신의 허브 사용자 이름으로 바꾸세요.
#
# ModuleNotFoundError: No module named 'optimum.exporters.onnx'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# 모델을 저장했으므로, 모델에 입력을 전달하기 위해 `InferenceSession` 객체를 만든다.

# %%
from onnxruntime import (GraphOptimizationLevel, InferenceSession,
                         SessionOptions)

def create_model_for_provider(model_path, provider="CPUExecutionProvider"):
    options = SessionOptions()
    options.intra_op_num_threads = 1
    options.graph_optimization_level = GraphOptimizationLevel.ORT_ENABLE_ALL
    session = InferenceSession(str(model_path), options, providers=[provider])
    session.disable_fallback()
    return session

# %%
onnx_model = create_model_for_provider(onnx_model_path)

# %%
inputs = clinc_enc["test"][:1]
del inputs["labels"]  # ONNX는 input_ids와 attention_mask 만 입력으로 기대하므로 label 열은 삭제
logits_onnx = onnx_model.run(None, inputs)[0]
logits_onnx.shape

# %%
np.argmax(logits_onnx)

# %%
clinc_enc["test"][0]["labels"]

# %% [markdown]
# ONNX 모델은 text_classification 파이프라인과 호환되지 않으므로 핵심 동작을 흉내 재는 사용자 정의 클래스를 만들자.

# %%
from scipy.special import softmax

class OnnxPipeline:
    def __init__(self, model, tokenizer):
        self.model = model
        self.tokenizer = tokenizer

    def __call__(self, query):
        model_inputs = self.tokenizer(query, return_tensors="pt")
        inputs_onnx = {k: v.cpu().detach().numpy()
                       for k, v in model_inputs.items()}
        logits = self.model.run(None, inputs_onnx)[0][0, :]
        probs = softmax(logits)
        pred_idx = np.argmax(probs).item()
        return [{"label": intents.int2str(pred_idx), "score": probs[pred_idx]}]

# %%
pipe = OnnxPipeline(onnx_model, tokenizer)
pipe(query)

# %%
class OnnxPerformanceBenchmark(PerformanceBenchmark):
    def __init__(self, *args, model_path, **kwargs):
        super().__init__(*args, **kwargs)
        self.model_path = model_path

    def compute_size(self):
        size_mb = Path(self.model_path).stat().st_size / (1024 * 1024)
        print(f"모델 크기 (MB) - {size_mb:.2f}")
        return {"size_mb": size_mb}

# %%
optim_type = "Distillation + ORT"
pb = OnnxPerformanceBenchmark(pipe, clinc["test"], optim_type,
                              model_path="onnx/model.onnx")
perf_metrics.update(pb.run_benchmark())

# %%
plot_metrics(perf_metrics, optim_type)

# %%
from onnxruntime.quantization import quantize_dynamic, QuantType

model_input = "onnx/model.onnx"
model_output = "onnx/model.quant.onnx"
quantize_dynamic(model_input, model_output, weight_type=QuantType.QInt8)

# %%
onnx_quantized_model = create_model_for_provider(model_output)
pipe = OnnxPipeline(onnx_quantized_model, tokenizer)
optim_type = "Distillation + ORT (quantized)"
pb = OnnxPerformanceBenchmark(pipe, clinc["test"], optim_type,
                              model_path=model_output)
perf_metrics.update(pb.run_benchmark())

# %%
plot_metrics(perf_metrics, optim_type)

# %% [markdown]
# ## 8.7 가중치 가지치기로 희소한 모델 만들기
# 신경망에서 가장 덜 중요한 가중치를 찾아 제거하는 방식으로 모델의 파라미터 개수를 줄이는 방법

# %% [markdown]
# ### 8.7.1 심층 신경망의 희소성
# - 모델이 점차 희소화되며, 희소 행렬 포맷으로 저장된다
# - 지치기와 양자화를 함께 사용하면 추가 압축이 가능하다

# %% [markdown]
# <img alt="Network Pruning" width="500" caption="Weights and neurons before and after pruning (courtesy of Song Han)" src="https://github.com/kikim6114/nlp2026-transformers/blob/main/images/chapter08_network-pruning.png?raw=1" id="network-pruning"/> <br>
# [그림 8-10] 가지치기 전후의 가중치와 뉴런(Song Han 제공)

# %% [markdown]
# ### 8.7.1 가중치 가지치기 방법

# %% [markdown]
# $$\text{Top}_k(\mathbf{S})_{ij}=\begin{cases} 1 & S_{ij}가 \, 최상위\, k \%인\, 경우, \\ 0 & 그\, 외의\, 경우 \end{cases} $$
#
# - $\mathbf{S}$: 중요도 점수(importance scores) 행렬
# - $k$: 희소성 비율을 제어하는 하이퍼파라미터($k$가 작을수록 행렬이 더 희소해진다).
# - 이 점수를 사용해 마스크 행렬(mask matrix) $\mathbf{M}$을 만든다. 이 행렬은 정방향 패스에서 입력 $x_i$에 곱해지는 가중치 $W_{ij}$를 마스킹해 희소한 활성화 $a_i$를 만든다:
#
# $$a_i = \sum_{j}{W_{ij}M_{ij}x_j}$$

# %% [markdown]
# #### 가지치기에서 고려할 것들
# - 어떤 가중치를 삭제할 것인가?
# - 최상의 성능을 내려면 남은 가중치를 어떻게 조정해야 하는가?
# - 이런 가지치기 계산을 효율적으로 수행하는 방법은 무엇인가?

# %% [markdown]
# #### 절댓값 가지치기
# 1. 중요도 점수 행렬을 학습한다: $ \mathbf{S}=(|W_{ij}|)_{1 \le j,\, j \le n} $
# 2. 마스크 행렬을 만든다: $\mathbf{\text M}=\text{Top}_k(\mathbf{S})$
# 3. 원하는 희소성에 도달하지 않았으면 1 단계로 간다.

# %% [markdown]
# #### 가지치기에 사용되는 세제곱 희소성 스케줄러
# - 희소성 초기값 $s_i$에서 출발하여 매 $\Delta t$ 스텝마다 $s_i$를 증가시켜 $N$ 단계 후에 희소성 최종값 $s_f$ 도달하게 한다.
# - 매 $\Delta t$ 스텝마다 이진 마스크 $\mathbf{\text M}$ 을 업데이트해 훈련하는 동안 마스킹된 가중치를 다시 활성화하고 가지치기로 인해 발행할지 모를 잠재적 정확도 손실을 복구하는 방법을 사용한다:
#
# $$ s_t = s_f + (s_i - s_f)\left(1-\frac{t-t_0}{N\Delta t}\right)^3, \,\,\,\, t \in \{t_0, t_0+\Delta t, ..., N\Delta t \}$$

# %%
# 가지치기에 사용되는 세제곱 희소성 스케줄러
import numpy as np
import matplotlib.pyplot as plt

def _sparsity(t, t_0=0, dt=1, s_i=0, s_f=0.9, N=100):
    return s_f + (s_i - s_f) * (1 - (t - t_0) / (N * dt))**3

steps = np.linspace(0,100,100)
values = [_sparsity(t) for t in steps]

fig, ax = plt.subplots()
ax.plot(steps, values)
ax.set_ylim(0,1)
ax.set_xlim(0,100)
ax.set_xlabel("Pruning step")
ax.set_ylabel("Sparsity")
plt.grid(linestyle="dashed")
plt.show()

# %% [markdown]
# 전이 학습에서는 가중치의 중요도가 주로 사전 훈련 단계에서 결정된다. 따라서 절댓값 가지치기로 인해 미세 튜닝 작업에서 중요한 가중치가 삭제될 수도 있다.

# %% [markdown]
# #### 이동 가지치기
# - 미세튜닝하는 동안 점진적으로 가중치를 제거해 모델을 점차 희소하게 만든다.
# - 미세튜닝 동안 가중치와 점수가 모두 학습된다
# - 원점으로부터 가장 크게 이동하는 가중치가 가장 중요한 가중치다.

# %% [markdown]
# <img alt="Magnitude vs Movement Pruning" width="700" caption="Comparison of weights removed (in gray) during magnitude pruning (left) and movement pruning (right)" src="https://github.com/kikim6114/nlp2026-transformers/blob/main/images/chapter08_magnitude-vs-movement.png?raw=1" id="magnitude-vs-movement"/> <br>
# [그림 8-12] 절댓값 가지치기(왼쪽)와 이동 가지치기(오른쪽)에서 삭제된 가중치 비교

# %% [markdown]
# <img alt="Pruning Distributions" width="500" caption="Distribution of remaining weights for magnitude pruning (MaP) and movement pruning (MvP)" src="https://github.com/kikim6114/nlp2026-transformers/blob/main/images/chapter08_pruning-dists.png?raw=1" id="pruning-dists"/> <br>
# [그림 8-13] 절댓값 가지치기(MaP)와 이동 가지치기(MvP)에서 남은 가중치

# %% [markdown]
# - 트랜스포머스는 기본적으로 가지치기 방법을 제공하지 않음.
# - 원래 이동 가지치기를 확장한 방법이 [`nn_pruning`(Neural Networks Block Movement Pruning)](https://huggingface.github.io/nn_pruning/) 라이브러리에 구현되어 있음.
# - 성능 최적화에 관심이 있다면 허깅페이스 [🤗 Optimum](https://huggingface.co/docs/optimum/v1.2.1/en/index)을 시도해보는 것도 좋겠다.

# %% [markdown]
# ## 결론
# #### 작지만 빠르고 정확도 높은 모델이 필요하다면?
# #### 예측 속도를 높이고 트랜스포머 모델의 메모리 사용량을 줄이는 기술 4 가지:
# - 지식 정제(Knowledge Distillation)
# - 양자화(Quantization)
# - ONNX 포맷과 ONNX 런타임(ORT)을 사용한 그래프 최적화(Graph Optimization)
# - 가지치기(Pruning)
#   - 트랜스포머 모델의 저장 크기를 줄이는 가장 효과적인 방법이지만,
#   - 하드웨어가 희소행렬 연산에 최적화되어야 가지치기의 효과를 제대로 볼 수 있다.

# %% [markdown]
# 그러나, 레이턴시 요구사항을 맞추려고 해쓰고 있거나, 모델이 컴퓨팅 자원을 독식하고 있다면 이러한 기법 중 하나를 시도해보기를 권한다.///
